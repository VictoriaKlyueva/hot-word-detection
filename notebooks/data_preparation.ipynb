# %%
import torch
from TTS.api import TTS
from IPython.display import Audio, display
import pyttsx3
import time
from gtts import gTTS
import os

# %%
tts = gTTS('aaa stones', lang='en', slow=False)
tts.save("tts.wav")

# %%
audio_file = "tts.wav"
display(Audio(audio_file))
