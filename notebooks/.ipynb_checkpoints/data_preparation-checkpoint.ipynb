# %%
import torch
from TTS.api import TTS
from IPython.display import Audio, display
import pyttsx3
import time

# %%
# Получить список голосов
voices = engine.getProperty('voices')
for voice in voices:
    print(f"ID: {voice.id}, Name: {voice.name}")
# Out:
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_DAVID_11.0, Name: Microsoft David Desktop - English (United States)
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_EN-US_ZIRA_11.0, Name: Microsoft Zira Desktop - English (United States)
# ID: HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_RU-RU_IRINA_11.0, Name: Microsoft Irina Desktop - Russian

# %%
engine = pyttsx3.init()

engine.setProperty('voice', "HKEY_LOCAL_MACHINE\SOFTWARE\Microsoft\Speech\Voices\Tokens\TTS_MS_RU-RU_IRINA_11.0")

# Настройки
engine.setProperty('rate', 180)    # Скорость
engine.setProperty('volume', 0.9)  # Громкость

engine.save_to_file('STONES', filename='stones5.wav')
engine.runAndWait()

# %%
tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2")
# Out:
#  > tts_models/multilingual/multi-dataset/xtts_v2 is already downloaded.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 tts = TTS("tts_models/multilingual/multi-dataset/xtts_v2")
#
# File ~\PycharmProjects\hot-word-detection\.venv\Lib\site-packages\TTS\api.py:74, in TTS.__init__(self, model_name, model_path, config_path, vocoder_path, vocoder_config_path, progress_bar, gpu)
#      72 if model_name is not None and len(model_name) > 0:
#      73     if "tts_models" in model_name:
# ---> 74         self.load_tts_model_by_name(model_name, gpu)
#      75     elif "voice_conversion_models" in model_name:
#      76         self.load_vc_model_by_name(model_name, gpu)
#
# File ~\PycharmProjects\hot-word-detection\.venv\Lib\site-packages\TTS\api.py:177, in TTS.load_tts_model_by_name(self, model_name, gpu)
# ...

# %%
tts.tts_to_file(text="stones", file_path="stones.wav", language="en", speaker="p225")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 tts.tts_to_file(text="stones", file_path="stones.wav", language="en", speaker="p225")
#
# File ~\PycharmProjects\hot-word-detection\.venv\Lib\site-packages\TTS\api.py:332, in TTS.tts_to_file(self, text, speaker, language, speaker_wav, emotion, speed, pipe_out, file_path, split_sentences, **kwargs)
#     290 def tts_to_file(
#     291     self,
#     292     text: str,
#    (...)    301     **kwargs,
#     302 ):
#     303     """Convert text to speech.
#     304
#     305     Args:
#    (...)    330             Additional arguments for the model.
#     331     """
# --> 332     self._check_arguments(speaker=speaker, language=language, speaker_wav=speaker_wav, **kwargs)
#     334     wav = self.tts(
#     335         text=text,
#     336         speaker=speaker,
#    (...)    340         **kwargs,
# ...

# %%
audio_file = "stones.wav"
display(Audio(audio_file))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
